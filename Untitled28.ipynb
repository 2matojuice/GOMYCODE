# %%
import pandas as pd
import numpy as np
exam_data = {'name': ['Anastasia', 'Dima', 'Katherine', 'James', 'Emily', 'Michael', 'Matthew', 'Laura', 'Kevin', 'Jonas'],

'score': [12.5, 9, 16.5, np.nan, 9, 20, 14.5, np.nan, 8, 19],

'attempts': [1, 3, 2, 3, 2, 3, 1, 1, 2, 1],

'qualify': ['yes', 'no', 'yes', 'no', 'no', 'yes', 'yes', 'no', 'no', 'yes'],

"labels" : ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']}

# %%
df=pd.DataFrame(exam_data)
df
# Out:
#         name  score  attempts qualify labels
# 0  Anastasia   12.5         1     yes      a
# 1       Dima    9.0         3      no      b
# 2  Katherine   16.5         2     yes      c
# 3      James    NaN         3      no      d
# 4      Emily    9.0         2      no      e
# 5    Michael   20.0         3     yes      f
# 6    Matthew   14.5         1     yes      g
# 7      Laura    NaN         1      no      h
# 8      Kevin    8.0         2      no      i
# 9      Jonas   19.0         1     yes      j

# %%
df = df.set_index("labels")
df
# Out:
#              name  score  attempts qualify
# labels
# a       Anastasia   12.5         1     yes
# b            Dima    9.0         3      no
# c       Katherine   16.5         2     yes
# d           James    NaN         3      no
# e           Emily    9.0         2      no
# f         Michael   20.0         3     yes
# g         Matthew   14.5         1     yes
# h           Laura    NaN         1      no
# i           Kevin    8.0         2      no
# j           Jonas   19.0         1     yes

# %%
print(df.head(3))
# Out:
#              name  score  attempts qualify
# labels
# a       Anastasia   12.5         1     yes
# b            Dima    9.0         3      no
# c       Katherine   16.5         2     yes

# %%
df = df.dropna()
df
# Out:
#              name  score  attempts qualify
# labels
# a       Anastasia   12.5         1     yes
# b            Dima    9.0         3      no
# c       Katherine   16.5         2     yes
# e           Emily    9.0         2      no
# f         Michael   20.0         3     yes
# g         Matthew   14.5         1     yes
# i           Kevin    8.0         2      no
# j           Jonas   19.0         1     yes

# %%
df[["name","score"]]
# Out:
#              name  score
# labels
# a       Anastasia   12.5
# b            Dima    9.0
# c       Katherine   16.5
# e           Emily    9.0
# f         Michael   20.0
# g         Matthew   14.5
# i           Kevin    8.0
# j           Jonas   19.0

# %%
df
# Out:
#              name  score  attempts qualify
# labels
# a       Anastasia   12.5         1     yes
# b            Dima    9.0         3      no
# c       Katherine   16.5         2     yes
# e           Emily    9.0         2      no
# f         Michael   20.0         3     yes
# g         Matthew   14.5         1     yes
# i           Kevin    8.0         2      no
# j           Jonas   19.0         1     yes

# %%
df

# %%
df = df.append(pd.DataFrame([new_row],index=['k'],columns=df.columns))
print(df)
# Out:
#         name  score  attempts qualify
# a  Anastasia   12.5         1     yes
# b       Dima    9.0         3      no
# c  Katherine   16.5         2     yes
# e      Emily    9.0         2      no
# f    Michael   20.0         3     yes
# g    Matthew   14.5         1     yes
# i      Kevin    8.0         2      no
# j      Jonas   19.0         1     yes
# k     Suresh   15.5         1     yes
# C:\Users\sarah\AppData\Local\Temp\ipykernel_48752\1208592029.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(pd.DataFrame([new_row],index=['k'],columns=df.columns))

# %%
df.drop("attempts", axis='columns')
# Out:
#         name  score qualify
# a  Anastasia   12.5     yes
# b       Dima    9.0      no
# c  Katherine   16.5     yes
# e      Emily    9.0      no
# f    Michael   20.0     yes
# g    Matthew   14.5     yes
# i      Kevin    8.0      no
# j      Jonas   19.0     yes
# k     Suresh   15.5     yes

# %%
df['Success'] = np.where(df['score'] > 10, '1', '0')
print(df)
# Out:
#         name  score  attempts qualify Success
# a  Anastasia   12.5         1     yes       1
# b       Dima    9.0         3      no       0
# c  Katherine   16.5         2     yes       1
# e      Emily    9.0         2      no       0
# f    Michael   20.0         3     yes       1
# g    Matthew   14.5         1     yes       1
# i      Kevin    8.0         2      no       0
# j      Jonas   19.0         1     yes       1
# k     Suresh   15.5         1     yes       1

# %%
df.to_csv('file_name.csv')

# %%
df
# Out:
#         name  score  attempts qualify Success
# a  Anastasia   12.5         1     yes       1
# b       Dima    9.0         3      no       0
# c  Katherine   16.5         2     yes       1
# e      Emily    9.0         2      no       0
# f    Michael   20.0         3     yes       1
# g    Matthew   14.5         1     yes       1
# i      Kevin    8.0         2      no       0
# j      Jonas   19.0         1     yes       1
# k     Suresh   15.5         1     yes       1
